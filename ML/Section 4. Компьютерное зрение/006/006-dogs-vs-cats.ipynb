# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.4.1
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data/train_sample/*.jpg')
test_files = glob('data/test_sample/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
[letter for letter in 'dfsdf']
# Out:
# ['d', 'f', 's', 'd', 'f']

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 100353
# =================================================================
# Total params: 7,735,617
# Trainable params: 100,353
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 5  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 25s 2s/step - loss: 317.1974 - accuracy: 0.6284 - val_loss: 69.0730 - val_accuracy: 0.8000
# Epoch 2/100
# 10/10 [==============================] - 24s 2s/step - loss: 1.3632 - accuracy: 0.9814 - val_loss: 217.3938 - val_accuracy: 0.8000
# Epoch 3/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.0487 - accuracy: 1.0000 - val_loss: 164.5453 - val_accuracy: 0.8000
# Epoch 4/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 143.7064 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 135.5743 - val_accuracy: 0.8000
# Epoch 6/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 132.4596 - val_accuracy: 0.8000
# Epoch 7/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 131.2691 - val_accuracy: 0.8000
# Epoch 8/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.8115 - val_accuracy: 0.8000
# Epoch 9/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.6493 - val_accuracy: 0.8000
# Epoch 10/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5751 - val_accuracy: 0.8000
# Epoch 11/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5527 - val_accuracy: 0.8000
# Epoch 12/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5469 - val_accuracy: 0.8000
# Epoch 13/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5224 - val_accuracy: 0.8000
# Epoch 14/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5087 - val_accuracy: 0.8000
# Epoch 15/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.5152 - val_accuracy: 0.8000
# Epoch 16/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4991 - val_accuracy: 0.8000
# Epoch 17/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4784 - val_accuracy: 0.8000
# Epoch 18/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4855 - val_accuracy: 0.8000
# Epoch 19/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4744 - val_accuracy: 0.8000
# Epoch 20/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4656 - val_accuracy: 0.8000
# Epoch 21/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4610 - val_accuracy: 0.8000
# Epoch 22/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4434 - val_accuracy: 0.8000
# Epoch 23/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 130.4329 - val_accuracy: 0.8000
# Epoch 24/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.4312 - val_accuracy: 0.8000
# Epoch 25/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.4082 - val_accuracy: 0.8000
# Epoch 26/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3916 - val_accuracy: 0.8000
# Epoch 27/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.4010 - val_accuracy: 0.8000
# Epoch 28/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3816 - val_accuracy: 0.8000
# Epoch 29/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3662 - val_accuracy: 0.8000
# Epoch 30/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3658 - val_accuracy: 0.8000
# Epoch 31/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3511 - val_accuracy: 0.8000
# Epoch 32/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3325 - val_accuracy: 0.8000
# Epoch 33/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3241 - val_accuracy: 0.8000
# Epoch 34/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.3057 - val_accuracy: 0.8000
# Epoch 35/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2921 - val_accuracy: 0.8000
# Epoch 36/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2933 - val_accuracy: 0.8000
# Epoch 37/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2673 - val_accuracy: 0.8000
# Epoch 38/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2563 - val_accuracy: 0.8000
# Epoch 39/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2587 - val_accuracy: 0.8000
# Epoch 40/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 130.2357 - val_accuracy: 0.8000
# Epoch 41/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.2103 - val_accuracy: 0.8000
# Epoch 42/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.2066 - val_accuracy: 0.8000
# Epoch 43/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1908 - val_accuracy: 0.8000
# Epoch 44/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1686 - val_accuracy: 0.8000
# Epoch 45/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1633 - val_accuracy: 0.8000
# Epoch 46/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1418 - val_accuracy: 0.8000
# Epoch 47/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1333 - val_accuracy: 0.8000
# Epoch 48/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.1274 - val_accuracy: 0.8000
# Epoch 49/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.0978 - val_accuracy: 0.8000
# Epoch 50/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.0767 - val_accuracy: 0.8000
# Epoch 51/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.0756 - val_accuracy: 0.8000
# Epoch 52/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.0515 - val_accuracy: 0.8000
# Epoch 53/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 130.0227 - val_accuracy: 0.8000
# Epoch 54/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 130.0217 - val_accuracy: 0.8000
# Epoch 55/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 130.0027 - val_accuracy: 0.8000
# Epoch 56/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.9861 - val_accuracy: 0.8000
# Epoch 57/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.9737 - val_accuracy: 0.8000
# Epoch 58/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.9483 - val_accuracy: 0.8000
# Epoch 59/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.9304 - val_accuracy: 0.8000
# Epoch 60/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.9212 - val_accuracy: 0.8000
# Epoch 61/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.8907 - val_accuracy: 0.8000
# Epoch 62/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.8665 - val_accuracy: 0.8000
# Epoch 63/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.8689 - val_accuracy: 0.8000
# Epoch 64/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 129.8420 - val_accuracy: 0.8000
# Epoch 65/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.8192 - val_accuracy: 0.8000
# Epoch 66/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.8116 - val_accuracy: 0.8000
# Epoch 67/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.7892 - val_accuracy: 0.8000
# Epoch 68/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.7631 - val_accuracy: 0.8000
# Epoch 69/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.7476 - val_accuracy: 0.8000
# Epoch 70/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.7221 - val_accuracy: 0.8000
# Epoch 71/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.7011 - val_accuracy: 0.8000
# Epoch 72/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.6951 - val_accuracy: 0.8000
# Epoch 73/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.6621 - val_accuracy: 0.8000
# Epoch 74/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.6439 - val_accuracy: 0.8000
# Epoch 75/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 129.6392 - val_accuracy: 0.8000
# Epoch 76/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.6089 - val_accuracy: 0.8000
# Epoch 77/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.5766 - val_accuracy: 0.8000
# Epoch 78/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.5656 - val_accuracy: 0.8000
# Epoch 79/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.5427 - val_accuracy: 0.8000
# Epoch 80/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.5135 - val_accuracy: 0.8000
# Epoch 81/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.5012 - val_accuracy: 0.8000
# Epoch 82/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.4726 - val_accuracy: 0.8000
# Epoch 83/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.4572 - val_accuracy: 0.8000
# Epoch 84/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 129.4452 - val_accuracy: 0.8000
# Epoch 85/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.4094 - val_accuracy: 0.8000
# Epoch 86/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.3821 - val_accuracy: 0.8000
# Epoch 87/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.3748 - val_accuracy: 0.8000
# Epoch 88/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.3449 - val_accuracy: 0.8000
# Epoch 89/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.3101 - val_accuracy: 0.8000
# Epoch 90/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.3031 - val_accuracy: 0.8000
# Epoch 91/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.2782 - val_accuracy: 0.8000
# Epoch 92/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.2556 - val_accuracy: 0.8000
# Epoch 93/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 129.2371 - val_accuracy: 0.8000
# Epoch 94/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.2059 - val_accuracy: 0.8000
# Epoch 95/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.1834 - val_accuracy: 0.8000
# Epoch 96/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.1721 - val_accuracy: 0.8000
# Epoch 97/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.1380 - val_accuracy: 0.8000
# Epoch 98/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.1109 - val_accuracy: 0.8000
# Epoch 99/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.1096 - val_accuracy: 0.8000
# Epoch 100/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 129.0794 - val_accuracy: 0.8000

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %%
# LogLoss = 1.04979
