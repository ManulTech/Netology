# %% [markdown]
# Лабораторная работа
# =====================
#
# Цель лабораторной работы получить практические знания по работе с признаками на известном датасете статистики самоубийств.
#
# Вам необходимо будет подготовить данные для обучения линейной модели предсказания количества самоубийств (столбец - suicides/100k pop).
#
# Чек-лист:
# 0. Изучите файл annotation.txt. Там содержится информация о датасете.
# 1. Загрузите датасет data.csv.
# 2. Посмотрите на данные. Отобразите общую информацию по признакам (вспомните о describe и info). Напишите в markdown свои наблюдения.
# 3. Выявите пропуски, а также возможные причины их возникновения. Решите, что следует сделать с ними. Напишите в markdown свои наблюдения.
# 4. Оцените зависимости переменных между собой. Используйте корреляции. Будет хорошо, если воспользуетесь profile_report. Напишите в markdown свои наблюдения.
# 5. Определите стратегию преобразования категориальных признаков (т.е. как их сделать адекватными для моделей).
# 6. Найдите признаки, которые можно разделить на другие, или преобразовать в другой тип данных. Удалите лишние, при необходимости.
# 7. Разделите выборку на обучаемую и тестовую.
# 8. Обучите линейную модель. Напишите в markdown свои наблюдения по полученным результатам.
#
# Если возникнут затруднения, то смотрите на материал практических занятий. Данного там должно хватить для выполнения всех пунктов. Желаю успеха!

# %% [markdown]
# ### Content
# This compiled dataset pulled from four other datasets linked by time and place, and was built to find signals correlated to increased suicide rates among different cohorts globally, across the socio-economic spectrum.
#
# ### References
# United Nations Development Program. (2018). Human development index (HDI). Retrieved from http://hdr.undp.org/en/indicators/137506
#
# World Bank. (2018). World development indicators: GDP (current US$) by country:1985 to 2016. Retrieved from http://databank.worldbank.org/data/source/world-development-indicators#
#
# [Szamil]. (2017). Suicide in the Twenty-First Century [dataset]. Retrieved from https://www.kaggle.com/szamil/suicide-in-the-twenty-first-century/notebook
#
# World Health Organization. (2018). Suicide prevention. Retrieved from http://www.who.int/mental_health/suicide-prevention/en/
#
# ### Inspiration
# Suicide Prevention.

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#       sex          age  suicides_no  population  suicides/100k pop  \
# 0    male  15-24 years           21      312900               6.71
# 1    male  35-54 years           16      308000               5.19
# 2  female  15-24 years           14      289700               4.83
# 3    male    75+ years            1       21800               4.59
# 4    male  25-34 years            9      274300               3.28
#
#   country-year  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0  Albania1987           NaN      2,156,624,900                 796
# 1  Albania1987           NaN      2,156,624,900                 796
# 2  Albania1987           NaN      2,156,624,900                 796
# 3  Albania1987           NaN      2,156,624,900                 796
# 4  Albania1987           NaN      2,156,624,900                 796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %% [markdown]
# Посмотрите на данные. Отобразите общую информацию по признакам (вспомните о describe и info). Напишите в markdown свои наблюдения.

# %%
df.isnull().sum()
# Out:
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df.describe()
# Out:
#         suicides_no    population  suicides/100k pop  HDI for year  \
# count  27820.000000  2.782000e+04       27820.000000   8364.000000
# mean     242.574407  1.844794e+06          12.816097      0.776601
# std      902.047917  3.911779e+06          18.961511      0.093367
# min        0.000000  2.780000e+02           0.000000      0.483000
# 25%        3.000000  9.749850e+04           0.920000      0.713000
# 50%       25.000000  4.301500e+05           5.990000      0.779000
# 75%      131.000000  1.486143e+06          16.620000      0.855000
# max    22338.000000  4.380521e+07         224.970000      0.944000
#
#        gdp_per_capita ($)
# count        27820.000000
# mean         16866.464414
# std          18887.576472
# min            251.000000
# 25%           3447.000000
# 50%           9372.000000
# 75%          24874.000000
# max         126352.000000

# %%
df.describe(include=object)
# Out:
#            sex          age country-year  gdp_for_year ($)     generation
# count    27820        27820        27820              27820         27820
# unique       2            6         2321               2321             6
# top     female  55-74 years  Austria1985      8,917,286,036  Generation X
# freq     13910         4642           12                 12          6408

# %% [markdown]
# Эти значения нужно перевести в скаляр

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sex                 27820 non-null  object
#  1   age                 27820 non-null  object
#  2   suicides_no         27820 non-null  int64
#  3   population          27820 non-null  int64
#  4   suicides/100k pop   27820 non-null  float64
#  5   country-year        27820 non-null  object
#  6   HDI for year        8364 non-null   float64
#  7    gdp_for_year ($)   27820 non-null  object
#  8   gdp_per_capita ($)  27820 non-null  int64
#  9   generation          27820 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Наблюдения
# 1. Максимальное значение suicides_no 22338, что странно и выглядит выбросом
# 2. population - ок
# 3. suicides/100k pop также большое максимально значение, нужно проверить
# 4. HDI for year - 19456 пропусков. Human Development Index (HDI). Definition: A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living.
# 5. gdp_per_capita - ок
# 6. sex - перевести в скаляр (one hot encoder)
# 7. age и generation - объединить и перевести в скаляр (one hot encoder)
# 8. country-year	- перевести в скаляр
# 9. gdp_for_year ()	- перевести в скаляр

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### suicides_no

# %%
plt.rcParams['figure.figsize']=(23,10)
sns.boxplot(data=df['suicides_no'])

# %%
df.loc[df['suicides_no'] > 4000]
# Out:
#           sex          age  suicides_no  population  suicides/100k pop  \
# 13367    male  35-54 years         6962    17833300              39.04
# 13378    male  55-74 years         4171     9374000              44.50
# 13379    male  35-54 years         7298    18094000              40.33
# 13391    male  35-54 years         6688    18218000              36.71
# 13403    male  35-54 years         6087    18287000              33.29
# ...       ...          ...          ...         ...                ...
# 27209    male  55-74 years         9068    32264697              28.11
# 27210    male  35-54 years        11634    41658010              27.93
# 27211    male  25-34 years         5503    22137097              24.86
# 27212    male  15-24 years         4359    22615073              19.27
# 27213  female  35-54 years         4053    41531809               9.76
#
#             country-year  HDI for year   gdp_for_year ($)   \
# 13367          Japan1985         0.791   1,398,892,744,821
# 13378          Japan1986           NaN   2,078,953,333,674
# 13379          Japan1986           NaN   2,078,953,333,674
# 13391          Japan1987           NaN   2,532,808,573,157
# 13403          Japan1988           NaN   3,071,683,013,179
# ...                  ...           ...                 ...
# 27209  United States2015           NaN  18,120,714,000,000
# 27210  United States2015           NaN  18,120,714,000,000
# 27211  United States2015           NaN  18,120,714,000,000
# 27212  United States2015           NaN  18,120,714,000,000
# 27213  United States2015           NaN  18,120,714,000,000
#
#        gdp_per_capita ($)       generation
# 13367               12401           Silent
# 13378               18288  G.I. Generation
# 13379               18288           Silent
# 13391               22137           Silent
# 13403               26687           Silent
# ...                   ...              ...
# 27209               60387          Boomers
# 27210               60387     Generation X
# 27211               60387       Millenials
# 27212               60387       Millenials
# 27213               60387     Generation X
#
# [278 rows x 10 columns]

# %% [markdown]
# #### Вывод по suicides_no: со значениями порядок

# %%
### Проверю колонку suicides/100k pop. Если она в порядке, то population / suicides_no должно равнятся suicides/100k pop
df.head()
# Out:
#       sex          age  suicides_no  population  suicides/100k pop  \
# 0    male  15-24 years           21      312900               6.71
# 1    male  35-54 years           16      308000               5.19
# 2  female  15-24 years           14      289700               4.83
# 3    male    75+ years            1       21800               4.59
# 4    male  25-34 years            9      274300               3.28
#
#   country-year  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0  Albania1987           NaN      2,156,624,900                 796
# 1  Albania1987           NaN      2,156,624,900                 796
# 2  Albania1987           NaN      2,156,624,900                 796
# 3  Albania1987           NaN      2,156,624,900                 796
# 4  Albania1987           NaN      2,156,624,900                 796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %%
df['suicides_no'] / (df['population'] / 100000)
# Out:
# 0        6.711409
# 1        5.194805
# 2        4.832585
# 3        4.587156
# 4        3.281079
#            ...
# 27815    2.955121
# 27816    2.582756
# 27817    2.172215
# 27818    1.671987
# 27819    1.459413
# Length: 27820, dtype: float64

# %%
### удаляю suicides_no	population

# %%
columns_to_drop = ['suicides_no', 'population']

# %% [markdown]
# #### country-year
# Очевидно, нужно расплитить

# %%
extract = r'([A-Za-z]+)([0-9]+)'
info_data = df['country-year'].str.extract(extract)

# %%
info_data
# Out:
#                 0     1
# 0         Albania  1987
# 1         Albania  1987
# 2         Albania  1987
# 3         Albania  1987
# 4         Albania  1987
# ...           ...   ...
# 27815  Uzbekistan  2014
# 27816  Uzbekistan  2014
# 27817  Uzbekistan  2014
# 27818  Uzbekistan  2014
# 27819  Uzbekistan  2014
#
# [27820 rows x 2 columns]

# %%
info_data.columns = ['country', 'year']
info_data['year'] = info_data['year'].astype(int)
info_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  27820 non-null  object
#  1   year     27820 non-null  int32
# dtypes: int32(1), object(1)
# memory usage: 326.1+ KB

# %%
columns_to_drop = ['suicides_no', 'population', 'country-year']

# %% [markdown]
# #### Теперь добавлю колонки

# %%
df['country'] = info_data['country']
df['year'] = info_data['year']
df
# Out:
#           sex          age  suicides_no  population  suicides/100k pop  \
# 0        male  15-24 years           21      312900               6.71
# 1        male  35-54 years           16      308000               5.19
# 2      female  15-24 years           14      289700               4.83
# 3        male    75+ years            1       21800               4.59
# 4        male  25-34 years            9      274300               3.28
# ...       ...          ...          ...         ...                ...
# 27815  female  35-54 years          107     3620833               2.96
# 27816  female    75+ years            9      348465               2.58
# 27817    male   5-14 years           60     2762158               2.17
# 27818  female   5-14 years           44     2631600               1.67
# 27819  female  55-74 years           21     1438935               1.46
#
#          country-year  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0         Albania1987           NaN      2,156,624,900                 796
# 1         Albania1987           NaN      2,156,624,900                 796
# 2         Albania1987           NaN      2,156,624,900                 796
# 3         Albania1987           NaN      2,156,624,900                 796
# 4         Albania1987           NaN      2,156,624,900                 796
# ...               ...           ...                ...                 ...
# 27815  Uzbekistan2014         0.675     63,067,077,179                2309
# 27816  Uzbekistan2014         0.675     63,067,077,179                2309
# 27817  Uzbekistan2014         0.675     63,067,077,179                2309
# 27818  Uzbekistan2014         0.675     63,067,077,179                2309
# 27819  Uzbekistan2014         0.675     63,067,077,179                2309
#
#             generation     country  year
# 0         Generation X     Albania  1987
# 1               Silent     Albania  1987
# 2         Generation X     Albania  1987
# 3      G.I. Generation     Albania  1987
# 4              Boomers     Albania  1987
# ...                ...         ...   ...
# 27815     Generation X  Uzbekistan  2014
# 27816           Silent  Uzbekistan  2014
# 27817     Generation Z  Uzbekistan  2014
# 27818     Generation Z  Uzbekistan  2014
# 27819          Boomers  Uzbekistan  2014
#
# [27820 rows x 12 columns]

# %% [markdown]
# #### HDI for year. Нашёл вот тут http://hdr.undp.org/en/data#

# %%
df_hdi = pd.read_csv('Human Development Index (HDI).csv', skiprows=[0], sep=',')
df_hdi.head()
# Out:
#   HDI Rank (2018)      Country   1990  Unnamed: 3   1991  Unnamed: 5   1992  \
# 0             170  Afghanistan  0.298         NaN  0.304         NaN  0.312
# 1              69      Albania  0.644         NaN  0.625         NaN  0.608
# 2              82      Algeria  0.578         NaN  0.582         NaN  0.589
# 3              36      Andorra     ..         NaN     ..         NaN     ..
# 4             149       Angola     ..         NaN     ..         NaN     ..
#
#    Unnamed: 7   1993  Unnamed: 9  ...   2014  Unnamed: 51   2015  Unnamed: 53  \
# 0         NaN  0.308         NaN  ...  0.488          NaN  0.490          NaN
# 1         NaN  0.611         NaN  ...  0.787          NaN  0.788          NaN
# 2         NaN  0.593         NaN  ...  0.749          NaN  0.751          NaN
# 3         NaN     ..         NaN  ...  0.853          NaN  0.850          NaN
# 4         NaN     ..         NaN  ...  0.557          NaN  0.565          NaN
#
#     2016  Unnamed: 55   2017  Unnamed: 57   2018  Unnamed: 59
# 0  0.491          NaN  0.493          NaN  0.496          NaN
# 1  0.788          NaN  0.789          NaN  0.791          NaN
# 2  0.755          NaN  0.758          NaN  0.759          NaN
# 3  0.854          NaN  0.852          NaN  0.857          NaN
# 4  0.570          NaN  0.576          NaN  0.574          NaN
#
# [5 rows x 60 columns]

# %%
hdi_columns = list(df_hdi.columns)

# %%
### удаляю пустые колонки

# %%
for column in hdi_columns:
    if 'Unnamed:' in column:
        df_hdi.drop([column], axis=1, inplace=True)
df_hdi.drop(['HDI Rank (2018)'], axis=1, inplace=True)
df_hdi
# Out:
#                                                Country   1990   1991   1992  \
# 0                                          Afghanistan  0.298  0.304  0.312
# 1                                              Albania  0.644  0.625  0.608
# 2                                              Algeria  0.578  0.582  0.589
# 3                                              Andorra     ..     ..     ..
# 4                                               Angola     ..     ..     ..
# ..                                                 ...    ...    ...    ...
# 202                          Least Developed Countries  0.350  0.353  0.354
# 203                     Small Island Developing States  0.595  0.598  0.603
# 204  Organization for Economic Co-operation and Dev...  0.785  0.790  0.788
# 205                                              World  0.598  0.601  0.601
# 206                                                NaN    NaN    NaN    NaN
#
#       1993   1994   1995   1996   1997   1998  ...   2009   2010   2011  \
# 0    0.308  0.303  0.327  0.331  0.335  0.339  ...  0.447  0.464  0.465
# 1    0.611  0.617  0.629  0.639  0.639  0.649  ...  0.729  0.740  0.759
# 2    0.593  0.597  0.602  0.610  0.619  0.629  ...  0.720  0.730  0.738
# 3       ..     ..     ..     ..     ..     ..  ...  0.830  0.828  0.827
# 4       ..     ..     ..     ..     ..     ..  ...  0.508  0.510  0.525
# ..     ...    ...    ...    ...    ...    ...  ...    ...    ...    ...
# 202  0.358  0.358  0.366  0.374  0.381  0.388  ...  0.477  0.485  0.493
# 203  0.608  0.612  0.618  0.624  0.629  0.632  ...  0.694  0.702  0.706
# 204  0.800  0.807  0.812  0.817  0.817  0.826  ...  0.868  0.873  0.877
# 205  0.608  0.611  0.617  0.622  0.624  0.631  ...  0.691  0.697  0.703
# 206    NaN    NaN    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN
#
#       2012   2013   2014   2015   2016   2017   2018
# 0    0.479  0.485  0.488  0.490  0.491  0.493  0.496
# 1    0.771  0.781  0.787  0.788  0.788  0.789  0.791
# 2    0.737  0.746  0.749  0.751  0.755  0.758  0.759
# 3    0.849  0.846  0.853  0.850  0.854  0.852  0.857
# 4    0.537  0.547  0.557  0.565  0.570  0.576  0.574
# ..     ...    ...    ...    ...    ...    ...    ...
# 202  0.499  0.504  0.510  0.516  0.520  0.525  0.528
# 203  0.704  0.708  0.712  0.717  0.719  0.722  0.723
# 204  0.879  0.883  0.886  0.889  0.892  0.894  0.895
# 205  0.708  0.713  0.718  0.722  0.727  0.729  0.731
# 206    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [207 rows x 30 columns]

# %%
#### делаю датафрейм с колонкой country и year для каждоый страны

# %%
df_hdi = df_hdi.set_index('Country').stack().reset_index(name='HDI for year')
df_hdi.rename(columns={'Country': 'country', 'level_1': 'year'}, inplace=True)
df_hdi.head()
# Out:
#        country  year HDI for year
# 0  Afghanistan  1990        0.298
# 1  Afghanistan  1991        0.304
# 2  Afghanistan  1992        0.312
# 3  Afghanistan  1993        0.308
# 4  Afghanistan  1994        0.303

# %%
df_hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       5974 non-null   object
#  1   year          5974 non-null   object
#  2   HDI for year  5974 non-null   object
# dtypes: object(3)
# memory usage: 140.1+ KB

# %% [markdown]
# #### но в HDI for year есть значения вида .. Заменю их на 0

# %%
df_hdi.loc[df_hdi['HDI for year'] == '..', 'HDI for year'].count()
# Out:
# 573

# %%
df_hdi.loc[df_hdi['HDI for year'] == '..', 'HDI for year'] = 0

# %%
df_hdi.loc[df_hdi['HDI for year'] == 0, 'HDI for year'].count()
# Out:
# 573

# %%
df_hdi['HDI for year'].isna().sum()
# Out:
# 0

# %%
df_hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       5974 non-null   object
#  1   year          5974 non-null   object
#  2   HDI for year  5974 non-null   object
# dtypes: object(3)
# memory usage: 140.1+ KB

# %%
# перевожу в числовой вид year и HDI for year

# %%
df_hdi['year'] = df_hdi['year'].astype(int)

# %%
#заменяю .. нулями

# %%
df_hdi.loc[df_hdi['HDI for year'] == '..', 'HDI for year'] = 0

# %%
#Пробую df_hdi['year'] = df_hdi['year'].astype(int)

# %%
df_hdi['HDI for year']  = df_hdi['HDI for year'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-be55dccdd486> in <module>
# ----> 1 df_hdi['HDI for year']  = df_hdi['HDI for year'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     565         self, dtype, copy: bool = False, errors: str = "raise"
#     566     ) -> "BlockManager":
# --> 567         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     568
#     569     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     394                 applied = b.apply(f, **kwargs)
#     395             else:
# --> 396                 applied = getattr(b, f)(**kwargs)
#     397             result_blocks = _extend_blocks(applied, result_blocks)
#     398
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     588             vals1d = values.ravel()
#     589             try:
# --> 590                 values = astype_nansafe(vals1d, dtype, copy=True)
#     591             except (ValueError, TypeError):
#     592                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     987     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     988         # Explicit copy, or required since NumPy can't view from / to object.
# --> 989         return arr.astype(dtype, copy=True)
#     990
#     991     return arr.view(dtype)
#
# ValueError: could not convert string to float:

# %%
# где-то остались строчки. Посмотрим где

# %%
my_list = []
def test(param):
    try:
        float(param)
    except:
        return my_list.append(param)

# %%
df_hdi['HDI for year'].apply(test).head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: HDI for year, dtype: object

# %%
my_list
# Out:
# [' ', ' ']

# %%
# в каких-то строках 2 пробела, заменю на 0

# %%
df_hdi.loc[df_hdi['HDI for year'] == ' ', 'HDI for year'] = 0

# %%
df_hdi['HDI for year']  = df_hdi['HDI for year'].astype(float)

# %%
df_hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       5974 non-null   object
#  1   year          5974 non-null   int32
#  2   HDI for year  5974 non-null   float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 116.8+ KB

# %%
df_hdi.head()
# Out:
#        country  year  HDI for year
# 0  Afghanistan  1990         0.298
# 1  Afghanistan  1991         0.304
# 2  Afghanistan  1992         0.312
# 3  Afghanistan  1993         0.308
# 4  Afghanistan  1994         0.303

# %%
df_hdi['year'] = df_hdi['year'].astype(int)

# %% [markdown]
# #### Теперь нужно добавить значения из df_hdi в df

# %%
# на всякий случай создаю 2 копии датафреймов, чтобы отработать код сначала там

# %%
df2 = df.copy()
df_hdi2 = df_hdi.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sex                 27820 non-null  object
#  1   age                 27820 non-null  object
#  2   suicides_no         27820 non-null  int64
#  3   population          27820 non-null  int64
#  4   suicides/100k pop   27820 non-null  float64
#  5   country-year        27820 non-null  object
#  6   HDI for year        8364 non-null   float64
#  7    gdp_for_year ($)   27820 non-null  object
#  8   gdp_per_capita ($)  27820 non-null  int64
#  9   generation          27820 non-null  object
#  10  country             27820 non-null  object
#  11  year                27820 non-null  int32
# dtypes: float64(2), int32(1), int64(3), object(6)
# memory usage: 2.4+ MB

# %%
df2['year'].min(), df2['year'].max(), df2['year'].count(), df2['country'].count()
# Out:
# (1985, 2016, 27820, 27820)

# %%
df_hdi2['year'].min(), df_hdi2['year'].max(), df_hdi2['year'].count(), df_hdi2['country'].count()
# Out:
# (1990, 2018, 5974, 5974)

# %%
#удалю из df2 данные страше 1990 года (<1990)

# %%
df2 = df2.drop(df2[df2.year < 1990].index)
df2.count()
# Out:
# sex                   24808
# age                   24808
# suicides_no           24808
# population            24808
# suicides/100k pop     24808
# country-year          24808
# HDI for year           7920
#  gdp_for_year ($)     24808
# gdp_per_capita ($)    24808
# generation            24808
# country               24808
# year                  24808
# dtype: int64

# %%
# Теперь удаляю данные старше 2016 года из df_hdi2:

# %%
df_hdi2 = df_hdi2.drop(df_hdi2[df_hdi2.year > 2016].index)
df_hdi2.count()
# Out:
# country         5562
# year            5562
# HDI for year    5562
# dtype: int64

# %%
df2['year'].min(), df2['year'].max(), df2['year'].count(), df2['country'].count()
# Out:
# (1990, 2016, 24808, 24808)

# %%
df_hdi2['year'].min(), df_hdi2['year'].max(), df_hdi2['year'].count(), df_hdi2['country'].count()
# Out:
# (1990, 2016, 5562, 5562)

# %%
#Составляю список стран, которые общие с df_hdi2

# %%
print(set(df2['country']).intersection(set(df_hdi2['country'])))
# Out:
# {'Argentina', 'Barbados', 'Poland', 'Israel', 'Armenia', 'Fiji', 'Kiribati', 'Colombia', 'Canada', 'Uruguay', 'Bahrain', 'Uzbekistan', 'Jamaica', 'Portugal', 'Mexico', 'Philippines', 'Suriname', 'France', 'Cuba', 'Qatar', 'Mauritius', 'Austria', 'Panama', 'Serbia', 'Turkmenistan', 'Cyprus', 'Estonia', 'Iceland', 'Belgium', 'Norway', 'Guatemala', 'Bahamas', 'Belize', 'Spain', 'Latvia', 'Maldives', 'Slovakia', 'Sweden', 'Ecuador', 'Germany', 'Azerbaijan', 'Slovenia', 'Denmark', 'Bulgaria', 'Georgia', 'Montenegro', 'Ireland', 'Croatia', 'Romania', 'Kuwait', 'Paraguay', 'Seychelles', 'Mongolia', 'Grenada', 'Kyrgyzstan', 'Belarus', 'Italy', 'Kazakhstan', 'Ukraine', 'Singapore', 'Albania', 'Switzerland', 'Japan', 'Guyana', 'Greece', 'Turkey', 'Malta', 'Netherlands', 'Brazil', 'Hungary', 'Luxembourg', 'Oman', 'Lithuania', 'Australia', 'Nicaragua', 'Finland', 'Thailand', 'Chile'}

# %%
countries_to_keep = set(df2['country']).intersection(set(df_hdi2['country']))

# %%
len(countries_to_keep)
# Out:
# 78

# %%
#Оставляю в df2 только общие с df_hdi2 страны (countries_to_keep). Опять же, можно было подумать о значении World. Не сегодня

# %%
df2['country'].nunique()
# Out:
# 100

# %%
df2['country'].count()
# Out:
# 24808

# %%
df_hdi2['country'].nunique()
# Out:
# 206

# %%
df_hdi2['country'].count()
# Out:
# 5562

# %%
df_hdi2 = df_hdi2.drop(df_hdi2.loc[~df_hdi2['country'].isin(countries_to_keep), :].index)

# %%
df_hdi2.count()
# Out:
# country         2106
# year            2106
# HDI for year    2106
# dtype: int64

# %%
df_hdi2['country'].nunique()
# Out:
# 78

# %%
df_hdi2['country'].count()
# Out:
# 2106

# %%
df_hdi2.head()
# Out:
#     country  year  HDI for year
# 29  Albania  1990         0.644
# 30  Albania  1991         0.625
# 31  Albania  1992         0.608
# 32  Albania  1993         0.611
# 33  Albania  1994         0.617

# %%
# выборочная проверка значений для одной страны

# %%
df2.loc[df2['country'] == 'Albania', ['year','HDI for year']].sort_values(by='year', ascending=True).head(10)
# Out:
#     year  HDI for year
# 36  1992           NaN
# 47  1992           NaN
# 46  1992           NaN
# 45  1992           NaN
# 43  1992           NaN
# 42  1992           NaN
# 44  1992           NaN
# 40  1992           NaN
# 39  1992           NaN
# 38  1992           NaN

# %%
df_hdi2.loc[df_hdi2['country'] == 'Albania', ['year','HDI for year']].sort_values(by='year', ascending=True).head(10)
# Out:
#     year  HDI for year
# 29  1990         0.644
# 30  1991         0.625
# 31  1992         0.608
# 32  1993         0.611
# 33  1994         0.617
# 34  1995         0.629
# 35  1996         0.639
# 36  1997         0.639
# 37  1998         0.649
# 38  1999         0.660

# %%
#Следующий код нашёл здесь https://coderoad.ru/29357379/Pandas-%D0%B7%D0%B0%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D1%8C-%D0%BD%D0%B5%D0%B4%D0%BE%D1%81%D1%82%D0%B0%D1%8E%D1%89%D0%B8%D0%B5-%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F-%D0%B2-dataframe-%D0%B8%D0%B7-%D0%B4%D1%80%D1%83%D0%B3%D0%BE%D0%B3%D0%BE-dataframe

# %%
df2 = df2.combine_first(df_hdi2)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25075 entries, 29 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0    gdp_for_year ($)   24808 non-null  object
#  1   HDI for year        9580 non-null   float64
#  2   age                 24808 non-null  object
#  3   country             25075 non-null  object
#  4   country-year        24808 non-null  object
#  5   gdp_per_capita ($)  24808 non-null  float64
#  6   generation          24808 non-null  object
#  7   population          24808 non-null  float64
#  8   sex                 24808 non-null  object
#  9   suicides/100k pop   24808 non-null  float64
#  10  suicides_no         24808 non-null  float64
#  11  year                25075 non-null  float64
# dtypes: float64(6), object(6)
# memory usage: 2.5+ MB

# %%
df2.isna().sum()
# Out:
#  gdp_for_year ($)       738
# HDI for year          13518
# age                     738
# country                   0
# country-year            738
# gdp_per_capita ($)      738
# generation              738
# population              738
# sex                     738
# suicides/100k pop       738
# suicides_no             738
# year                      0
# dtype: int64

# %%
df2.isna().head()
# Out:
#     gdp_for_year ($)   HDI for year   age  country  country-year  \
# 0                True         False  True    False          True
# 1                True         False  True    False          True
# 2                True         False  True    False          True
# 3                True         False  True    False          True
# 4                True         False  True    False          True
#
#    gdp_per_capita ($)  generation  population   sex  suicides/100k pop  \
# 0                True        True        True  True               True
# 1                True        True        True  True               True
# 2                True        True        True  True               True
# 3                True        True        True  True               True
# 4                True        True        True  True               True
#
#    suicides_no   year
# 0         True  False
# 1         True  False
# 2         True  False
# 3         True  False
# 4         True  False

# %%
df2.loc[df2['HDI for year'] == False, :]
# Out:
#       gdp_for_year ($)   HDI for year          age  country country-year  \
# 87        3,314,898,292           0.0  15-24 years  Albania  Albania1996
# 88        3,314,898,292           0.0    75+ years  Albania  Albania1996
# 89        3,314,898,292           0.0  25-34 years  Albania  Albania1996
# 90        3,314,898,292           0.0  35-54 years  Albania  Albania1996
# 91        3,314,898,292           0.0  35-54 years  Albania  Albania1996
# ...                 ...           ...          ...      ...          ...
# 5677                NaN           0.0          NaN  Regions          NaN
# 5678                NaN           0.0          NaN  Regions          NaN
# 5679                NaN           0.0          NaN  Regions          NaN
# 5680                NaN           0.0          NaN  Regions          NaN
# 5681                NaN           0.0          NaN  Regions          NaN
#
#       gdp_per_capita ($)       generation  population     sex  \
# 87                1127.0     Generation X    287700.0  female
# 88                1127.0  G.I. Generation     41200.0  female
# 89                1127.0     Generation X    267900.0  female
# 90                1127.0          Boomers    379600.0    male
# 91                1127.0          Boomers    362000.0  female
# ...                  ...              ...         ...     ...
# 5677                 NaN              NaN         NaN     NaN
# 5678                 NaN              NaN         NaN     NaN
# 5679                 NaN              NaN         NaN     NaN
# 5680                 NaN              NaN         NaN     NaN
# 5681                 NaN              NaN         NaN     NaN
#
#       suicides/100k pop  suicides_no    year
# 87                 5.56         16.0  1996.0
# 88                 4.85          2.0  1996.0
# 89                 3.73         10.0  1996.0
# 90                 3.16         12.0  1996.0
# 91                 2.49          9.0  1996.0
# ...                 ...          ...     ...
# 5677                NaN          NaN  2012.0
# 5678                NaN          NaN  2013.0
# 5679                NaN          NaN  2014.0
# 5680                NaN          NaN  2015.0
# 5681                NaN          NaN  2016.0
#
# [452 rows x 12 columns]

# %%
# После изменения вижу, что год заполнился:

# %%
df2.loc[df2['country'] == 'Albania', ['year','HDI for year']].head(10)
# Out:
#       year  HDI for year
# 29  1990.0         0.644
# 30  1991.0         0.625
# 31  1992.0         0.608
# 32  1993.0         0.611
# 33  1994.0         0.617
# 34  1995.0         0.629
# 35  1996.0         0.639
# 36  1992.0         0.639
# 37  1992.0         0.649
# 38  1992.0         0.660

# %%
#проверю, те ли значения взяты из df_hdi2

# %%
df_hdi2.loc[df_hdi2['country'] == 'Albania', ['year','HDI for year']].head(10)
# Out:
#     year  HDI for year
# 29  1990         0.644
# 30  1991         0.625
# 31  1992         0.608
# 32  1993         0.611
# 33  1994         0.617
# 34  1995         0.629
# 35  1996         0.639
# 36  1997         0.639
# 37  1998         0.649
# 38  1999         0.660

# %%
df2.head()
# Out:
#     gdp_for_year ($)   HDI for year  age  country country-year  \
# 29                NaN         0.644  NaN  Albania          NaN
# 30                NaN         0.625  NaN  Albania          NaN
# 31                NaN         0.608  NaN  Albania          NaN
# 32                NaN         0.611  NaN  Albania          NaN
# 33                NaN         0.617  NaN  Albania          NaN
#
#     gdp_per_capita ($) generation  population  sex  suicides/100k pop  \
# 29                 NaN        NaN         NaN  NaN                NaN
# 30                 NaN        NaN         NaN  NaN                NaN
# 31                 NaN        NaN         NaN  NaN                NaN
# 32                 NaN        NaN         NaN  NaN                NaN
# 33                 NaN        NaN         NaN  NaN                NaN
#
#     suicides_no    year
# 29          NaN  1990.0
# 30          NaN  1991.0
# 31          NaN  1992.0
# 32          NaN  1993.0
# 33          NaN  1994.0
