# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import math
import sympy

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.misc import derivative, electrocardiogram
from scipy.optimize import minimize, approx_fprime, fmin, brute
from scipy.signal import find_peaks

# %matplotlib inline

# %% [markdown]
# # Функции

# %% [markdown]
# Построим функцию $$f(x)=\frac{1}{1-x}$$

# %%
x = np.linspace(-3.0, 3.0, 1000)
y = np.array([1/(1-x_i) for x_i in x])
plt.plot(x, y)
plt.show()
# Out:
# C:\Users\aekom\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# Какова область определения? Какова область значения?

# %% [markdown]
# Построим функцию $$f(x)=2^{x}$$

# %%
x = np.linspace(-100.0, 100.0, 1000)
y = np.array([math.pow(2, x_i) for x_i in x])
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Способы представления функций

# %% [markdown]
# **Программный способ представления.**
#
# Дана функция: ![alt text](https://pp.userapi.com/c854520/v854520891/aaadd/f5M6W-fRFjg.jpg). Напишем для неё код.

# %%
def func(x):
    stepen = 1/4*math.pow(x, 5) - math.pow(x, 4) + 1/4*math.pow(x, 3) + 3/2*math.pow(x, 2) +1
    y = 1 - pow(2, stepen)
    return y

# %% [markdown]
# **Графический способ представления функции.**

# %% [markdown]
# Нарисуем график написанной функции:

# %%
# создаем вектор x
x1 = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для вектора y
y1 = [func(x1[i]) for i in range(len(x1))]

plt.plot(x1, y1)
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %%
x1
# Out:
# array([-3.        , -2.93939394, -2.87878788, -2.81818182, -2.75757576,
#        -2.6969697 , -2.63636364, -2.57575758, -2.51515152, -2.45454545,
#        -2.39393939, -2.33333333, -2.27272727, -2.21212121, -2.15151515,
#        -2.09090909, -2.03030303, -1.96969697, -1.90909091, -1.84848485,
#        -1.78787879, -1.72727273, -1.66666667, -1.60606061, -1.54545455,
#        -1.48484848, -1.42424242, -1.36363636, -1.3030303 , -1.24242424,
#        -1.18181818, -1.12121212, -1.06060606, -1.        , -0.93939394,
#        -0.87878788, -0.81818182, -0.75757576, -0.6969697 , -0.63636364,
#        -0.57575758, -0.51515152, -0.45454545, -0.39393939, -0.33333333,
#        -0.27272727, -0.21212121, -0.15151515, -0.09090909, -0.03030303,
#         0.03030303,  0.09090909,  0.15151515,  0.21212121,  0.27272727,
#         0.33333333,  0.39393939,  0.45454545,  0.51515152,  0.57575758,
#         0.63636364,  0.6969697 ,  0.75757576,  0.81818182,  0.87878788,
#         0.93939394,  1.        ,  1.06060606,  1.12121212,  1.18181818,
#         1.24242424,  1.3030303 ,  1.36363636,  1.42424242,  1.48484848,
#         1.54545455,  1.60606061,  1.66666667,  1.72727273,  1.78787879,
#         1.84848485,  1.90909091,  1.96969697,  2.03030303,  2.09090909,
#         2.15151515,  2.21212121,  2.27272727,  2.33333333,  2.39393939,
#         2.45454545,  2.51515152,  2.57575758,  2.63636364,  2.6969697 ,
#         2.75757576,  2.81818182,  2.87878788,  2.93939394,  3.        ])

# %% [markdown]
# **Представление функции ввиде формулы.**

# %% [markdown]
# Иногда удобно представить функцию ввиде нескольких формул вместо одной. Например, функция y=abs(x). Если мы хотим записать алгоритм функции, легче всего разделить пространство аргументов на плоскости на 2 отрезка: от $-\infty$ до 0 включительно и от 0 до $+\infty $

# %% [markdown]
# ![alt text](https://pp.userapi.com/c858028/v858028826/2c07f/SOjKZptkdXU.jpg)

# %% [markdown]
# # Полиномиальные функции или многочлены.

# %% [markdown]
# Целая рациональная функция (также полиномиальная функция) — числовая функция одного действительного переменного вида:
# $$f(x) = a_{n}x^{n}+a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x+a_{0}=\sum_{i=0}^{n}a_{i}x^{i}$$,
# где $n\in \mathbb{N}, a_{n},a_{n-1},...,a_{2},a_{1},a_{0}\in \mathbb{R}, a_{n}\neq 0$

# %% [markdown]
# **Пример построения полинома: степень = 0.**

# %% [markdown]
# коэффициент a = 3

# %%
x1 = np.linspace(-3.0, 3.0, 100)
y1 = [3 for _ in range(len(x1))]
plt.plot(x1, y1, '-o')
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Пример построения полинома степени 2: подбрасывание мяча**

# %%
def polynom_2(x):
    y = -4.9*x*x + 6.1*x + 1.4
    return y

x1 = np.linspace(-0.25, 1.5, 100)
y1 = [polynom_2(x1[i]) for i in range(len(x1))]
plt.plot(x1, y1, '-o')
plt.title('График функции полинома степени 2: траектория мяча')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Пример построения полинома степени 2: Golden Gate в Сан-Франсиско**

# %%
def polynom_golden_gate(x):
    y = 0.00037*x*x - 0.475*x + 230
    return y

x1 = np.linspace(-1000, 2300, 100)
y1 = [polynom_golden_gate(x1[i]) for i in range(len(x1))]
plt.figure(figsize=(20,4))
plt.plot(x1, y1, '-o')
plt.title('График функции полинома степени 2: Golden Gate в Сан-Франсиско')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# # Предел

# %%
x = np.array([i for i in range(-1000, 1000)])
y = np.array([math.sin(math.radians(x_i))/x_i for x_i in x])
plt.plot(x, y)
plt.show()
# Out:
# C:\Users\aekom\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# Вычислим значение предела функции в точке x = 0

# %%
x = sympy.symbols('x') 
expr = sympy.sin(x)/x; 
    
print("Expression : {}".format(expr))  
      
# Use sympy.limit() method  
limit_expr = sympy.limit(expr, x, 0)   
      
print("Limit of the expression tends to 0 : {}".format(limit_expr))
# Out:
# Expression : sin(x)/x
# Limit of the expression tends to 0 : 1

# %% [markdown]
# # Примеры пределов

# %% [markdown]
# **Пример 1**

# %% [markdown]
# Построим график функции $$f(x)=(1+x)^{\frac{1}{x}}$$

# %%
x = np.linspace(-100, 100, 1000)
y = np.array([(1+x_i)**(1/x_i) for x_i in x])

plt.plot(x, y)
plt.show()
# Out:
# /home/orange/new_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# При x->0 значение функции не известно

# %%
print((1+0)**(1/0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-335-b0dda14ede2a> in <module>
# ----> 1 print((1+0)**(1/0))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Если мы рассмотрим значение функции при x->0+, то значение функции будет стремиться к 2,72 (это число является экспонентой)

# %% [markdown]
# x = 0.0001

# %%
print((1+0.0001)**(1/0.0001))
# Out:
# 2.7181459268249255

# %% [markdown]
# x = 0.0000001

# %%
print((1+0.0000001)**(1/0.0000001))
# Out:
# 2.7182816941320818

# %% [markdown]
# Если мы рассмотрим предел слевам (когда x->0-), то значение функции будет стремиться к числу 2,72

# %%
print((1-0.0000001)**(1/-0.0000001))
# Out:
# 2.7182819629423656

# %% [markdown]
# Предел в точке x = 0 стремится к константе exp = 2.72

# %%
print(math.exp(1))
# Out:
# 2.718281828459045

# %% [markdown]
# **Предел 2**

# %% [markdown]
# Построим функцию $$f(x)=1/x$$

# %% [markdown]
# Функция неограниченно растет при приближении к x->0

# %%
x = np.linspace(-100, 100, 1999)
y = np.array([1/x_i for x_i in x])

plt.plot(x, y)
plt.show()
# Out:
# /home/orange/new_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# # Исследование функции с помощью производных

# %% [markdown]
# **Сгенерированный пример**

# %% [markdown]
# Посмотрим данные, сгенерированные с помощью уравнения синуса

# %%
x = np.array([i for i in range(-1000, 1000)])
y = np.array([math.sin(math.radians(x_i)) for x_i in x])
plt.plot(x, y)

# %% [markdown]
# Первая производная

# %%
list_der_sin = []
for i in range(len(x)-1):
    list_der_sin.append((y[i+1]-y[i])/(x[i+1]-x[i]))
list_der_sin.append(list_der_sin[-1])

# %%
fig, axs = plt.subplots(2,figsize=(20,10))
axs[0].set_title('Исходная: sin(x)')
axs[0].plot(x, y)
axs[1].set_title('Первая производная функции: sin`(x) = cos(x)')
axs[1].plot(x, list_der_sin)
axs[1].plot(x, [0 for i in range(len(list_der_sin))], '-')

# %% [markdown]
# Вторая производная

# %%
list_second_der_sin = []
for i in range(len(x)-1):
    list_second_der_sin.append((list_der_sin[i+1]-list_der_sin[i])/(x[i+1]-x[i]))
list_second_der_sin.append(list_second_der_sin[-1])
list_second_der_sin
# Out:
# [1.7629842144760918e-06,
#  1.7730201004028854e-06,
#  1.7825425419992225e-06,
#  1.791547683991264e-06,
#  1.8000318172032697e-06,
#  1.8079913800048693e-06,
#  1.8154229595642533e-06,
#  1.8223232931821436e-06,
#  1.8286892695009333e-06,
#  1.8345179297413166e-06,
#  1.8398064688321102e-06,
#  1.8445522365386044e-06,
#  1.848752738544174e-06,
#  1.8524056374578038e-06,
#  1.8555087538214775e-06,
#  1.8580600670485616e-06,
#  1.8600577162803121e-06,
#  1.8615000013126363e-06,
#  1.8623853833313809e-06,
#  1.8627124857011093e-06,
#  1.8624800946667377e-06,
#  1.8616871600565974e-06,
#  1.8603327958542728e-06,
#  1.8584162807764258e-06,
#  1.8559370588575978e-06,
#  1.852894739856558e-06,
#  1.8492890996954966e-06,
#  1.845120080934222e-06,
#  1.840387792969892e-06,
#  1.8350925123896847e-06,
#  1.8292346832766123e-06,
#  1.8228149172510328e-06,
#  1.8158339937512138e-06,
#  1.8082928599993961e-06,
#  1.800192631214206e-06,
#  1.791534590416149e-06,
#  1.782320188461339e-06,
#  1.7725510440232551e-06,
#  1.7622289432621911e-06,
#  1.751355839715032e-06,
#  1.7399338541349008e-06,
#  1.727965273990539e-06,
#  1.715452553286028e-06,
#  1.7023983120299719e-06,
#  1.688805335972024e-06,
#  1.6746765758755556e-06,
#  1.6600151470818113e-06,
#  1.644824329023927e-06,
#  0.0,
#  0.0]

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная: sin(x)')
axs[0].plot(x, y)
axs[1].set_title('Первая производная функции: sin`(x) = cos(x)')
axs[1].plot(x, list_der_sin)
axs[1].plot(x, [0 for i in range(len(list_der_sin))], '-')
axs[2].set_title('Вторая производная функции: cos`(x) = -sin(x)')
axs[2].plot(x, list_second_der_sin)
axs[2].plot(x, [0 for i in range(len(list_der_sin))], '-')

# %% [markdown]
# **Реальный пример**

# %% [markdown]
# Рассмотрим график подъема человека по стене. Нам нужно определить, когда человек спустился с верхней точки.

# %%
data = pd.read_csv('data/video.csv')
data.head()
# Out:
#    sec   x1    y1    x2    y2  height
# 0    0  875  1411  1008  1835     414
# 1    1  883  1377  1057  1873     417
# 2    2  862  1397  1066  1872     417
# 3    3  878  1394  1046  1875     417
# 4    4  910  1378  1070  1866     417

# %%
plt.figure(figsize=(20,4))
plt.plot(data.height)
plt.xlabel('время')
plt.ylabel('изменение высоты по времени')
# Out:
# Text(0, 0.5, 'изменение высоты по времени')

# %% [markdown]
# Как найти точку подъема и точку спуска?

# %% [markdown]
# Построим график производной

# %%
list_ids = data.sec.unique()
list_derivatives = []
for i in range(len(list_ids)-1):
    sec_id_next = list_ids[i+1]
    sec_id = list_ids[i]
    height = list(data.loc[data.sec==sec_id, 'height'])[0]
    next_height = list(data.loc[data.sec==sec_id_next, 'height'])[0]
    list_derivatives.append((next_height - height)/(sec_id_next - sec_id))
list_derivatives.append(list_derivatives[-1])
data['first_derivative'] = list_derivatives

# %% [markdown]
# Построим график второй производной

# %%
list_ids = data.sec.unique()
second_list_derivatives = []
for i in range(len(list_ids)-1):
    sec_id_next = list_ids[i+1]
    sec_id = list_ids[i]
    derivative = list(data.loc[data.sec==sec_id, 'first_derivative'])[0]
    next_derivative = list(data.loc[data.sec==sec_id_next, 'first_derivative'])[0]
    if (next_height - height) == 0:
        second_list_derivatives.append(-10)    
    else:
        second_list_derivatives.append((next_derivative - derivative)/(sec_id_next - sec_id))
second_list_derivatives.append(second_list_derivatives[-1])
data['second_derivative'] = second_list_derivatives

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная')
axs[0].plot([i for i in range(0, len(data))], data.height)
axs[1].set_title('Первая производная функции')
axs[1].plot([i for i in range(0, len(data['first_derivative']))], data['first_derivative'])
axs[2].set_title('Вторая производная функции')
axs[2].plot([i for i in range(0, len(data['second_derivative']))], data['second_derivative'])

# %% [markdown]
# Построим график изменения высоты для одного пролаза

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная')
axs[0].plot([i for i in range(0, 200)], data.height[:200])
axs[1].set_title('Первая производная функции')
axs[1].plot([i for i in range(0, 200)], data['first_derivative'][:200])
axs[1].plot([i for i in range(200)], [0 for i in range(200)], '-')
axs[2].set_title('Вторая производная функции')
axs[2].plot([i for i in range(0, 200)], data['second_derivative'][:200])
axs[2].plot([i for i in range(200)], [0 for i in range(200)], '-')

# %% [markdown]
# Найдем точку топа (когда человек достиг самой высокой точки) с помощью команды **find_peaks** и атрибутов **prominence** и **width**:
#
# **prominence**: The prominence of a peak measures how much a peak stands out from the surrounding baseline of the signal and is defined as the vertical distance between the peak and its lowest contour line.

# %% [markdown]
# **width**: Required width of peaks in samples. Either a number, None, an array matching x or a 2-element sequence of the former. The first element is always interpreted as the minimal and the second, if supplied, as the maximal required width.

# %% [markdown]
# Команда find_peaks: https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.find_peaks.html

# %%
peaks, _ = find_peaks(data.height, prominence=1, width=20)
plt.plot(data.height)
plt.plot(peaks, data.height[peaks], "x")
plt.show()

# %% [markdown]
# ### Поиск экстремумов

# %%
def f(x):
    return -1 * np.sin(x)/x

# %%
def f_(x):
    return -f(x)

# %% [markdown]
# ### Поиск локальных минимумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.128375
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 19
#          Function evaluations: 38

# %% [markdown]
# ### Поиск локальных максимумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f_,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f_, x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.217234
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.217234
#          Iterations: 13
#          Function evaluations: 26

# %% [markdown]
# ### Производная

# %%
from scipy.misc import derivative
def f(x):
    return x**3 + x**2
derivative(f, 1.0, dx=1e-6)
# Out:
# 4.999999999921734

# %% [markdown]
# derivative(f, 1.0, dx=1e-6):
# *   given a function, use a central difference formula with spacing dx to compute the n-th derivative at x0.
# *   1.0 - the point at which n-th derivative is found
# *   dx - spacing

# %%
def f(x):
    return x ** 2 + 1

# %%
x = np.linspace(-10, 10)
fx = f(x)
f1x = [derivative(f, xx, dx=1e-6, n=1) for xx in x]

# %%
fig, axs = plt.subplots(2,figsize=(10,10))
axs[0].set_title('Исходная')
axs[0].plot(x, fx, label='function')
axs[1].set_title('Первая производная функции')
axs[1].plot(x, f1x, label='derivative')

# %% [markdown]
# ### Частные производные

# %%
def func(x, c0, c1):
    "Coordinate vector `x` should be an array of size two."
    return c0 * x[0]**2 + c1 * x[1]**2

# %%
x = np.ones(2)
c0, c1 = (1, 2)
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, func, [eps, eps], c0, c1)
# Out:
# array([2.        , 4.00000003])

# %% [markdown]
# ### Вычисление частных производных

# %% [markdown]
# Хотим посчитать частные производные функции $f(x,y)=x^3y-x^2y^2+x-1$ в точке (1, 1)
#
# $f'_x=3x^2y-2xy^2+1$
#
# $f'_y=x^3-2x^2y$
#
# $f'_x(1,1)=3-2+1=2$
#
# $f'_y(1,1)=1-2=-1$
#
# $grad_f(1,1) = (2, -1)$

# %% [markdown]
# # Пример оптимизационной задачи

# %% [markdown]
# Вектора. Загрузим датасет "Hessen House Prices Dataset" из kaggle (https://www.kaggle.com/orgesleka/hessen-house-prices-dataset). 1 вектор в данной таблице - это один дом с различными показателями.

# %%
url="http://yustiks.ru/dataset/houses.json"
df=pd.read_json(url)
df.head()
# Out:
#    posterid           Haustyp Angebotstyp  Wohnflaeche__m²_ Zimmer   abtest  \
# 0  50316225   einfamilienhaus     Angebot               160      6  control
# 1  50379245  mehrfamilienhaus     Angebot               160    8.0  control
# 2  40815451   einfamilienhaus     Angebot               120      4  control
# 3  49513983   einfamilienhaus     Angebot               140      5  control
# 4  49797192   einfamilienhaus     Angebot                80      4  control
#
#      plz  Verkaeufer yo_m  Baujahr  ...  Verfuegbar_ab_Jahr Dachboden  \
# 0  33378  gewerblich    A   1928.0  ...                 NaN       NaN
# 1  65207  gewerblich    A   1968.0  ...                 NaN       NaN
# 2  54647  gewerblich    A   1750.0  ...                 NaN       NaN
# 3   7646  gewerblich    A   2017.0  ...                 NaN       NaN
# 4  54597  gewerblich    A   1900.0  ...                 NaN       NaN
#
#    Verfuegbar_ab_Monat Nebenkosten__in_€_  Kaution__in_€_ Haustiere_erlaubt  \
# 0                  NaN                NaN             NaN               NaN
# 1                  NaN                NaN             NaN               NaN
# 2                  NaN                NaN             NaN               NaN
# 3                  NaN                NaN             NaN               NaN
# 4                  NaN                NaN             NaN               NaN
#
#   Warmmiete__in_€_  Heizkosten__in_€_ WG_geeignet Denkmalobjekt
# 0              NaN                NaN         NaN           NaN
# 1              NaN                NaN         NaN           NaN
# 2              NaN                NaN         NaN           NaN
# 3              NaN                NaN         NaN           NaN
# 4              NaN                NaN         NaN           NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# Три атрибута - год покупки, цена на дом, и метраж (сколько метров представляет собой жил площадь)

# %%
df = df[['Baujahr', 'ExactPreis', 'Wohnflaeche__m²_']]

# %%
df = df.dropna()

# %%
plt.scatter(df['Baujahr'], df['Wohnflaeche__m²_'])

# %%
x = np.array(df[['Baujahr', 'Wohnflaeche__m²_']])
y = np.array(df['ExactPreis'])

# %%
import random

# m denotes the number of examples here, not the number of features
def gradientDescent(x, y, theta, alpha, m, numIterations):
    xTrans = x.transpose()
    for i in range(0, numIterations):
        hypothesis = np.dot(x, theta)
        loss = hypothesis - y
        # avg cost per example (the 2 in 2*m doesn't really matter here.
        # But to be consistent with the gradient, I include it)
        cost = np.sum(loss ** 2) / (2 * m)
        print("Iteration %d | Cost: %f" % (i, cost))
        # avg gradient per example
        gradient = np.dot(xTrans, ) / m
        # update
        theta = theta - alpha * gradient
    return theta


def genData(numPoints, bias, variance):
    x = np.zeros(shape=(numPoints, 2))
    y = np.zlosseros(shape=numPoints)
    # basically a straight line
    for i in range(0, numPoints):
        # bias feature
        x[i][0] = 1
        x[i][1] = i
        # our target variable
        y[i] = (i + bias) + random.uniform(0, 1) * variance
    return x, y

#gen 100 points with a bias of 25 and 10 variance as a bit of noise
x, y = genData(100, 25, 10)
m, n = np.shape(x)
numIterations= 100
alpha = 0.0005
theta = np.ones(n)
theta = gradientDescent(x, y, theta, alpha, m, numIterations)
print(theta)
# Out:
# Iteration 0 | Cost: 419.322970
# Iteration 1 | Cost: 237.285199
# Iteration 2 | Cost: 162.211289
# Iteration 3 | Cost: 131.240949
# Iteration 4 | Cost: 118.455492
# Iteration 5 | Cost: 113.168069
# Iteration 6 | Cost: 110.972255
# Iteration 7 | Cost: 110.051183
# Iteration 8 | Cost: 109.655720
# Iteration 9 | Cost: 109.476982
# Iteration 10 | Cost: 109.387607
# Iteration 11 | Cost: 109.335083
# Iteration 12 | Cost: 109.297758
# Iteration 13 | Cost: 109.266703
# Iteration 14 | Cost: 109.238238
# Iteration 15 | Cost: 109.210844
# Iteration 16 | Cost: 109.183896
# Iteration 17 | Cost: 109.157136
# Iteration 18 | Cost: 109.130458
# Iteration 19 | Cost: 109.103817
# Iteration 20 | Cost: 109.077195
# Iteration 21 | Cost: 109.050585
# Iteration 22 | Cost: 109.023985
# Iteration 23 | Cost: 108.997392
# Iteration 24 | Cost: 108.970806
# Iteration 25 | Cost: 108.944226
# Iteration 26 | Cost: 108.917654
# Iteration 27 | Cost: 108.891089
# Iteration 28 | Cost: 108.864530
# Iteration 29 | Cost: 108.837978
# Iteration 30 | Cost: 108.811433
# Iteration 31 | Cost: 108.784894
# Iteration 32 | Cost: 108.758362
# Iteration 33 | Cost: 108.731837
# Iteration 34 | Cost: 108.705319
# Iteration 35 | Cost: 108.678807
# Iteration 36 | Cost: 108.652302
# Iteration 37 | Cost: 108.625804
# Iteration 38 | Cost: 108.599313
# Iteration 39 | Cost: 108.572828
# Iteration 40 | Cost: 108.546350
# Iteration 41 | Cost: 108.519878
# Iteration 42 | Cost: 108.493414
# Iteration 43 | Cost: 108.466956
# Iteration 44 | Cost: 108.440505
# Iteration 45 | Cost: 108.414060
# Iteration 46 | Cost: 108.387623
# Iteration 47 | Cost: 108.361192
# Iteration 48 | Cost: 108.334767
# Iteration 49 | Cost: 108.308350
# Iteration 50 | Cost: 108.281939
# Iteration 51 | Cost: 108.255534
# Iteration 52 | Cost: 108.229137
# Iteration 53 | Cost: 108.202746
# Iteration 54 | Cost: 108.176362
# Iteration 55 | Cost: 108.149985
# Iteration 56 | Cost: 108.123614
# Iteration 57 | Cost: 108.097250
# Iteration 58 | Cost: 108.070892
# Iteration 59 | Cost: 108.044542
# Iteration 60 | Cost: 108.018198
# Iteration 61 | Cost: 107.991860
# Iteration 62 | Cost: 107.965530
# Iteration 63 | Cost: 107.939206
# Iteration 64 | Cost: 107.912888
# Iteration 65 | Cost: 107.886578
# Iteration 66 | Cost: 107.860274
# Iteration 67 | Cost: 107.833977
# Iteration 68 | Cost: 107.807686
# Iteration 69 | Cost: 107.781402
# Iteration 70 | Cost: 107.755125
# Iteration 71 | Cost: 107.728854
# Iteration 72 | Cost: 107.702590
# Iteration 73 | Cost: 107.676333
# Iteration 74 | Cost: 107.650083
# Iteration 75 | Cost: 107.623839
# Iteration 76 | Cost: 107.597601
# Iteration 77 | Cost: 107.571371
# Iteration 78 | Cost: 107.545147
# Iteration 79 | Cost: 107.518930
# Iteration 80 | Cost: 107.492719
# Iteration 81 | Cost: 107.466515
# Iteration 82 | Cost: 107.440318
# Iteration 83 | Cost: 107.414127
# Iteration 84 | Cost: 107.387943
# Iteration 85 | Cost: 107.361765
# Iteration 86 | Cost: 107.335595
# Iteration 87 | Cost: 107.309430
# Iteration 88 | Cost: 107.283273
# Iteration 89 | Cost: 107.257122
# Iteration 90 | Cost: 107.230978
# Iteration 91 | Cost: 107.204840
# Iteration 92 | Cost: 107.178709
# Iteration 93 | Cost: 107.152585
# Iteration 94 | Cost: 107.126467
# Iteration 95 | Cost: 107.100356
# Iteration 96 | Cost: 107.074252
# Iteration 97 | Cost: 107.048154
# Iteration 98 | Cost: 107.022063
# Iteration 99 | Cost: 106.995978
# [1.36988964 1.42875919]

# %%
plt.scatter(x[:,1], y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Пример функции №2:

# %%
def eggholder(x):
    return (-(x[1] + 47) * np.sin(np.sqrt(abs(x[0]/2 + (x[1]  + 47))))
            -x[0] * np.sin(np.sqrt(abs(x[0] - (x[1]  + 47)))))

bounds = [(-512, 512), (-512, 512)]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.arange(-512, 513)
y = np.arange(-512, 513)
xgrid, ygrid = np.meshgrid(x, y)
xy = np.stack([xgrid, ygrid])

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(45, -45)
ax.plot_surface(xgrid, ygrid, eggholder(xy), cmap='terrain')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('eggholder(x, y)')
plt.show()
