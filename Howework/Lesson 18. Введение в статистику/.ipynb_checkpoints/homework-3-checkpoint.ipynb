# %% [markdown]
# # Домашняя работа №3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline
import statistics
import ssl

# %% [markdown]
# Загрузить датасет по url:

# %%
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
# все данные загружаются с сервера
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)

# %% [markdown]
# Более подробно о датасете можно прочитать по [данной ссылке](https://data.world/promptcloud/world-happiness-report-2019) или по [ссылке в kaggle](https://www.kaggle.com/PromptCloudHQ/world-happiness-report-2019)

# %% [markdown]
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness that ranks 156 countries by how happy their citizens perceive themselves to be. This year’s World Happiness Report focuses on happiness and the community: how happiness has evolved over the past dozen years, with a focus on the technologies, social norms, conflicts and government policies that have driven those changes.

# %% [markdown]
# *  **Country (region)** Name of the country.
# *  **Ladder** Cantril Ladder is a measure of life satisfaction.
# *  **SD of Ladder** Standard deviation of the ladder.
# *  **Positive affect** Measure of positive emotion.
# *  **Negative affect** Measure of negative emotion.
# *  **Social support** The extent to which Social support contributed to the calculation of the Happiness Score.
# *  **Freedom** The extent to which Freedom contributed to the calculation of the Happiness Score.
# *  **Corruption** The extent to which Perception of Corruption contributes to Happiness Score.
# *  **Generosity** The extent to which Generosity contributed to the calculation of the Happiness Score.
# *  **Log of GDP per capita** The extent to which GDP contributes to the calculation of the Happiness Score.
# *  **Healthy life expectancy** The extent to which Life expectancy contributed to the calculation of the Happiness Score.

# %% [markdown]
# Посмотреть первые несколько рядов таблицы

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df.shape
# Out:
# (156, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (region)         156 non-null    object
#  1   Ladder                   156 non-null    int64
#  2   SD of Ladder             156 non-null    int64
#  3   Positive affect          155 non-null    float64
#  4   Negative affect          155 non-null    float64
#  5   Social support           155 non-null    float64
#  6   Freedom                  155 non-null    float64
#  7   Corruption               148 non-null    float64
#  8   Generosity               155 non-null    float64
#  9   Log of GDP
# per capita    152 non-null    float64
#  10  Healthy life
# expectancy  150 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %%
df.isnull().sum().sum()
# Out:
# 23

# %%
df = df.dropna(axis=0, how='any') 
# убираю все строчки, где есть NaN. Если этого не сделать, 
# то далее значения медианы среднее и пр. будут другими
# по хорошему нужно посмотреть, что там за значения и можно ли их удалить или заменить на среднее

# %% [markdown]
# #Частотный график показывает как часто встречается значение,  а не его размер. То есть 15 и 16 это сколько раз встречались значения в заданных интервалах. А сами значения меньше 15 попадают интервал 0-20.

# %% [markdown]
# Построить частотный график для двух параметров: Freedom и positive affect. Какое это распределение?

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(df['Freedom'], 200, facecolor='b')

plt.xlabel('Freedom')
plt.ylabel('frequency')
plt.title('Частотный график Freedom (разбиение интервала по 200 элементов)')
plt.grid(True)
plt.show()

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(df['Positive affect'], 200, facecolor='b')

plt.xlabel('frequency')
plt.ylabel('Positive affect')
plt.title('Частотный график Freedom (разбиение интервала по 200 элементов)')
plt.grid(True)
plt.show()

# %% [markdown]
# Найти медиану, моду, математическое ожидание, стандартное отклонение,  дисперсию, минимум и максимум, найти выбросы (если есть), размах для колонки Freedom

# %% [markdown]
# #### это равномерное распределение, так как нет пиков

# %%
df['Freedom'].median()
# Out:
# 79.5

# %%
df['Freedom'].nunique()
# Out:
# 140

# %%
df['Freedom'].mode() ### тут все значения разные, поэтому выдал 140
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        5.0
# 4        6.0
#        ...
# 135    150.0
# 136    151.0
# 137    152.0
# 138    154.0
# 139    155.0
# Length: 140, dtype: float64

# %%
df['Freedom'].mean() # матожидание (среднее)
# Out:
# 78.82857142857142

# %%
minimum = df.agg({'Freedom': ['min']})['Freedom'][0]
maximum = df.agg({'Freedom': ['max']})['Freedom'][0]
avg = df.agg({'Freedom': ['mean']})['Freedom'][0]
minimum, maximum, avg
# Out:
# (1.0, 155.0, 78.82857142857142)

# %%
#Размах
diff = maximum - minimum
diff
# Out:
# 154.0

# %% [markdown]
# Почему нельзя найти моду?

# %% [markdown]
# Потому что нет значений, которые повторяются дважды. Они все мода

# %% [markdown]
# ### Выбросы

# %%
df.loc[pd.isna(df.Freedom), :] #видно, что пустых значений нет, потому что ранее делал df = df.dropna(axis=0, how='any')
# Out:
# Empty DataFrame
# Columns: [Country (region), Ladder, SD of Ladder, Positive affect, Negative affect, Social support, Freedom, Corruption, Generosity, Log of GDP
# per capita, Healthy life
# expectancy]
# Index: []

# %%
freedom = df['Freedom']
pa = df['Positive affect']
fig, ax = plt.subplots()
ax.scatter(freedom, pa, c='green', alpha=0.3, edgecolors='none')

ax.grid(True)
plt.xlabel('Freedom')
plt.ylabel('Positive affect')
plt.show()

# %% [markdown]
# Аномальных значений нет. Вывод: выбросов нет

# %% [markdown]
# ### Cтандартное отклонение

# %%
# покажет NaN если есть пустые значения
freedom = df['Freedom']
statistics.pstdev(freedom)
# Out:
# 44.9475794449399

# %%
df.Freedom.std() ## отличается от предыдущего значения. Если возвести в квадрат, то получится df.Freedom.var()
# почему statistics.pstdev(freedom) показывает другое значение??
# Out:
# 45.108971631877274

# %% [markdown]
# ### Дисперсия

# %%
df.Freedom.var()
# Out:
# 2034.8193216855084

# %% [markdown]
# Посмотреть корреляцию между Freedom и positive affect (графически и математически). Графически - plt.scatter, математически - посчитать коэффициент Пирсона. О чем говорит знак коэффициента?

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(freedom, pa)
plt.scatter(freedom, pa, marker='.')
print('Коэффициент корреляции Пирсона:', corr)
# Out:
# Коэффициент корреляции Пирсона: 0.696567045809068

# %% [markdown]
# #### Положительный коэффициент говорит о том, что чем больше свободы, тем больше положительный affect

# %% [markdown]
# Нормализовать данные колонки Freedom (централизация + масштабирование)

# %% [markdown]
# ### Центрирование

# %%
f1 = freedom - avg ### из всех значений вычитаю среднее по колонке freedom

# %%
min(f1)
# Out:
# -77.82857142857142

# %%
max(f1)
# Out:
# 76.17142857142858

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))

f1_scaled = min_max_scaler.fit_transform(df[['Freedom']])
df_norm = pd.DataFrame(f1_scaled)
df_norm.head()
# Out:
#           0
# 0 -0.948052
# 1 -0.935065
# 2 -0.974026
# 3 -0.922078
# 4 -0.766234

# %%
print('Максимум после нормализации: ', max(f1_scaled), '\n', 'Минимум после нормализации: ', min(f1_scaled))
# Out:
# Максимум после нормализации:  [1.]
#  Минимум после нормализации:  [-1.]

# %% [markdown]
# Построить матрицу корреляций для всех колонок таблицы

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# Загрузить таблицу цен на авокадо:

# %%
df=pd.read_csv('data/avocado.csv')
df[:3]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %% [markdown]
# Сделать частотный график колонки AveragePrice. Какое это распределение?

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(df['AveragePrice'], 10, facecolor='b')

plt.xlabel('Average Price')
plt.ylabel('frequency')
plt.title('Частотный график AveragePrice (разбиение интервала по 200 элементов)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### это нормальное распределение, потому что есть пик и похож на шляпу

# %% [markdown]
# Найти корреляцию в следующих колонках:

# %% [markdown]
# колонкой 4046, 4225, 4770 и Average Price. Если корелляция есть (обратная или прямая), то какие выводы можно сделать?

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# ### есть обратная корреляция между 4046, 4225, 4770 и Average Price. Значит, чем выше значение в колонках 4046, 4225, 4770, тем меньше средняя цена
